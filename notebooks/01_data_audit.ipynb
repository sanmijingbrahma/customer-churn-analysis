# %% [markdown]
# # Customer Churn Dataset Audit
#
# ## Objective
# - How many rows and columns are there
# - What columns are there
# - What datatypes each have
# - Are there any Missing and Duplicate values
# - Which Columns are numerical and categorical
# - What is the target columns
# - Is there any suspicious values thta is need of cleaning

# %% [markdown]
# ## Import Libraries and setup data

# %%
import pandas as pd

df = pd.read_csv("../data/raw/Telco_Churn_Dataset.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Dataset Shape

# %%
rows, cols = df.shape

print(f"Rows : {rows}")
print(f"Columns : {cols}")
# Out:
# Rows : 7043
# Columns : 21

# %% [markdown]
# ## Columns of Dataset

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ## Data Typs

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# - Here we see that total charges is stored as object which should be numerical.
# -

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Numerical Columns

# %%
df.select_dtypes(include="number").columns.tolist()
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges']

# %% [markdown]
# ## Categorical Columns

# %%
df.select_dtypes(include="object").columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ## Initial Observation
# - Dataset Contains 7043 Rows and 21 columns
# - Numerical Features
#     - SeniorCitizen
#     - tenure
#     - MonthlyCharges
#     - Total Charges
# - Categorical Features
#     - customerID
#     - SeniorCitizen
#     - gender
#     - Partner
#     - Dependents
#     - PhoneService
#     - MultipleLines
#     - InternetSErrvice
#     - OnlineSecurity
#     - OnlineBackup
#     - DeviceProtection
#     - TechSupport
#     - StreamingTV
#     - StreamingMovies
#     - Contract
#     - PaperlessBilling
#     - PaymentMethod
#     - Churn
# - Here Churn is our target column
# - No missing values were found
# - No duplicate values were found
# - Total Charges are stored as categorical it should be numerical
# - Suspicious Findings
#     - TotalChargest stored as object
#     - Several service columns contains like "No internet service" instead of just no

# %% [markdown]
# ## Conclusion
# The dataset has been audited and it's overall structure is understood. Both Numerical and categorical feature have been identified, also we have found out there were no missing and duplicate values, but in numerical their might be potential outliers.
